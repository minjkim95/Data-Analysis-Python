# %% [markdown]
# #### This markdown is for practice in train and test in model evaluation

# %%
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100) # mean 3, standard dev 1
y = numpy.random.normal(150, 40, 100) / x # mean 150, st.dev 40

plt.scatter(x, y)
plt.show()

# %%
# Split into the dataset into train and test set
train_x = x[:80]
test_x = x[80:]

train_y = y[:80]
test_y = y[80:]

# %%
test_x
# Out:
# array([2.81053074, 2.92278133, 3.82470301, 4.24821292, 2.59610773,
#        1.61548133, 4.36723542, 4.21788563, 2.53799465, 3.35088849,
#        3.38186623, 3.56627544, 3.20420798, 4.40669624, 1.2620405 ,
#        4.04082395, 3.38047197, 2.78286473, 4.1735315 , 0.65639681])

# %%
test_y
# Out:
# array([ 72.37873053,  55.46264153,  34.46826737,  40.15213735,
#         70.55883508, 108.46604975,  21.035144  ,  32.35727584,
#         64.76189111,  52.19177448,  55.71813453,  50.5667094 ,
#         32.65308038,  27.61777936,  80.14230427,  54.98360439,
#         46.50723143,  61.85229524,  45.84155234, 208.47130994])

# %%
# Display training set
plt.scatter(train_x, train_y)
plt.show()

# %%
# Display test set
plt.scatter(test_x, test_y)
plt.show()

# %%
# Fit the dataset 
# Draw a polynomial regression line through the data points
mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

myline = numpy.linspace(0, 6, 100)

plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
# r2 score to measure the relationship between x and y 
from sklearn.metrics import r2_score

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

r2 = r2_score(train_y, mymodel(train_x))

print(r2)
# Out:
# 0.7988645544629798

# %%
# test model with testing data
mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

r2 = r2_score(test_y, mymodel(test_x))

print(r2)
# Out:
# 0.8086921460343658

# %%
# predict new values with the model
print(mymodel(5))
# Out:
# 22.879625918122656
